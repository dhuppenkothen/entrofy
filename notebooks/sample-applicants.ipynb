# %%
# !pip install names
import names
import numpy
import pandas as pd
# Out:
# Requirement already satisfied (use --upgrade to upgrade): names in ./anaconda3/lib/python3.4/site-packages

# %%
num_applicants = 300

# uses numpy.random.choice to weight each category
# _categories and _probability can be modified and extended, but each array must be of equal length
# contains missing values, because we expect those in source data

gender_categories = ['male','female','other','']
gender_probability = [.48,.48,.03,.01]

career_categories = ['grad-student','junior-faculty','senior-faculty','']
career_probability = [.33,.33,.33,.01]

country_categories = ['OECD','non-OECD',''] # see http://www.oecd.org/about/membersandpartners/
country_probability = [.49,.49,.02]

subfield_categories = ['solar','cosmology','astrophysics','exoplanets','']
subfield_probability = [.24,.24,.24,.24,.04]

first_time_categories = ['first_time','returning','']
first_time_probability = [.49,.49,.02]

# %%
gender_array = numpy.random.choice(gender_categories, p=gender_probability,size=num_applicants,replace=True)
name_array = [names.get_full_name(gender=i) for i in gender_array]
career_stage_array = numpy.random.choice(career_categories, p=career_probability,size=num_applicants,replace=True)
country_array = numpy.random.choice(country_categories, p=country_probability,size=num_applicants,replace=True)
subfield_array = numpy.random.choice(subfield_categories, p=subfield_probability,size=num_applicants,replace=True)
first_time_array = numpy.random.choice(first_time_categories,p=first_time_probability,size=num_applicants,replace=True)

# %%
df2 = pd.DataFrame({
        'name':name_array,
        'gender':gender_array,
        'career_stage':career_stage_array,
        'country':country_array,
        'subfield':subfield_array,
        'first_time':first_time_array
        })

df2
# Out:
#        career_stage   country  first_time  gender                name  \
# 0      grad-student      OECD  first_time  female       Tammy Urbanek
# 1      grad-student  non-OECD   returning  female        Candice Buhl
# 2    junior-faculty      OECD   returning    male        Joshua Allan
# 3    senior-faculty      OECD  first_time  female      Nancy Thompson
# 4    senior-faculty  non-OECD   returning  female      Molly Williams
# 5      grad-student      OECD  first_time    male        Jose Stewart
# 6    junior-faculty      OECD  first_time   other      Deborah Munson
# 7      grad-student      OECD  first_time  female        Erica Norris
# 8    junior-faculty      OECD                male         James Adams
# 9    junior-faculty  non-OECD  first_time    male     Jeffrey Shaddox
# 10   senior-faculty  non-OECD   returning    male     James Mcconnell
# 11   senior-faculty  non-OECD   returning    male          John Scott
# 12   junior-faculty      OECD  first_time  female        Selma Dahlen
# 13   senior-faculty      OECD   returning  female         Marian Denk
# 14     grad-student      OECD              female            Ma Baker
# 15   junior-faculty      OECD  first_time  female   Jessica Beresford
# 16   junior-faculty  non-OECD  first_time                Billy Garner
# 17   senior-faculty  non-OECD  first_time    male       Henry Flowers
# 18   junior-faculty  non-OECD  first_time  female        Mary Kearney
# 19   senior-faculty      OECD   returning  female      Gertrude Begum
# 20     grad-student  non-OECD   returning  female  Elisabeth Langford
# 21     grad-student  non-OECD  first_time  female      Lisa Fulbright
# 22   senior-faculty      OECD   returning  female       Ginger Miller
# 23   junior-faculty      OECD   returning    male         Edwin Dumas
# 24     grad-student  non-OECD  first_time  female    Norene Mackinnon
# 25     grad-student      OECD   returning    male         John Dudley
# 26   senior-faculty  non-OECD   returning    male         John Aldana
# 27     grad-student  non-OECD   returning    male      Michael Grimes
# 28   junior-faculty  non-OECD   returning    male        Harold Orosz
# 29     grad-student  non-OECD  first_time    male       Joshua Garcia
# ..              ...       ...         ...     ...                 ...
# 270    grad-student  non-OECD  first_time  female         Lorena Lane
# 271  senior-faculty  non-OECD  first_time  female        Mavis Coffie
# 272    grad-student  non-OECD   returning  female      Shirley Glueck
# 273  junior-faculty      OECD   returning    male         Kyle Roland
# 274    grad-student  non-OECD   returning  female        Wendy Venson
# 275  junior-faculty  non-OECD  first_time    male        Blaine Sharp
# 276    grad-student      OECD   returning    male     Leonard Cordero
# 277  senior-faculty  non-OECD   returning   other        Kirk Lehmann
# 278  junior-faculty      OECD  first_time    male       Joseph Winsor
# 279    grad-student      OECD  first_time  female      Dolores Colony
# 280    grad-student  non-OECD   returning    male         Kyle Stokes
# 281  senior-faculty  non-OECD  first_time    male        William Rios
# 282  junior-faculty  non-OECD  first_time    male       Francis Krebs
# 283  senior-faculty      OECD  first_time    male     James Patterson
# 284  senior-faculty  non-OECD   returning    male        Ricky Mcbean
# 285  senior-faculty      OECD  first_time  female          Jill Hinde
# 286  junior-faculty      OECD   returning    male      Joseph Pelcher
# 287    grad-student      OECD  first_time    male      Paul Tomlinson
# 288    grad-student      OECD  first_time    male          Leroy Hall
# 289  junior-faculty  non-OECD   returning    male        Mark Mcbride
# 290    grad-student  non-OECD   returning  female         Joyce Pratt
# 291    grad-student  non-OECD   returning  female     Lillian Wheeler
# 292    grad-student  non-OECD   returning    male       William Ervin
# 293  senior-faculty      OECD  first_time  female      Beverly Ingram
# 294    grad-student      OECD   returning  female        Tara Sholtis
# 295    grad-student      OECD  first_time  female      Vernie Kolesar
# 296    grad-student      OECD  first_time  female      Connie Eveland
# 297    grad-student      OECD   returning    male         Eric Guzman
# 298  junior-faculty      OECD  first_time    male         Luis Maness
# 299  senior-faculty      OECD   returning    male       Manuel Grothe
#
#          subfield
# 0       cosmology
# 1       cosmology
# 2      exoplanets
# 3    astrophysics
# 4       cosmology
# 5       cosmology
# 6      exoplanets
# 7    astrophysics
# 8           solar
# 9           solar
# 10          solar
# 11   astrophysics
# 12     exoplanets
# 13   astrophysics
# 14   astrophysics
# 15     exoplanets
# 16   astrophysics
# 17
# 18   astrophysics
# 19          solar
# 20      cosmology
# 21     exoplanets
# 22   astrophysics
# 23      cosmology
# 24      cosmology
# 25     exoplanets
# 26
# 27   astrophysics
# 28   astrophysics
# 29   astrophysics
# ..            ...
# 270         solar
# 271         solar
# 272  astrophysics
# 273    exoplanets
# 274  astrophysics
# 275     cosmology
# 276  astrophysics
# 277     cosmology
# 278         solar
# 279    exoplanets
# 280    exoplanets
# 281         solar
# 282  astrophysics
# 283     cosmology
# 284     cosmology
# 285     cosmology
# 286         solar
# 287    exoplanets
# 288
# 289         solar
# 290    exoplanets
# 291    exoplanets
# 292     cosmology
# 293    exoplanets
# 294         solar
# 295  astrophysics
# 296  astrophysics
# 297  astrophysics
# 298     cosmology
# 299     cosmology
#
# [300 rows x 6 columns]

# %%
df2.to_csv('datasets/all-even-300.csv',index=False)
